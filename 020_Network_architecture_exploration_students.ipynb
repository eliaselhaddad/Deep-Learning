# %% [markdown]
# # Network Architecture Exploration: Understanding Underfitting and Overfitting
# ## Background
# This exercise aims to demonstrate how different neural network architectures can lead to underfitting or overfitting. You will experiment with various configurations of a fully connected neural network to observe these phenomena.
#
# ## Underfitting
# Occurs when a model is too simple to capture the underlying pattern of the data. Often caused by having too few layers or neurons.
#
# ## Overfitting
# Happens when a model learns the training data too well, including the noise, making it perform poorly on new, unseen data. This can result from having too many layers or neurons.

# %% [markdown]
# ## Setup
# Import the necessary libraries and prepare the dataset.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# Generate synthetic data
X, y = make_circles(n_samples=6000, noise=0.09, factor=0.5, random_state=42)

# Splitting the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Visualize the dataset
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdBu)
plt.title("Training Data")
plt.show()
# Out:
# 2023-11-24 10:15:23.481153: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-24 10:15:23.619547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 10:15:23.619638: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 10:15:23.634553: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 10:15:23.688474: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-24 10:15:23.689773: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 10:15:24.687783: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Model Building
# Define a function to create a model with a variable number of layers and neurons.

# %%
def build_model(num_layers=1, num_neurons=10, activation_function='sigmoid'):
    model = tf.keras.models.Sequential()
    
    model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function, input_shape=(2,)))
    
    for _ in range(num_layers - 1):
        model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function))
        
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Train and Evaluate Model Script
# Below is a skeleton for a function to train and evaluate your models. Fill in the missing parts as indicated by the comments.

# %%
def train_and_evaluate_model(model, epochs=50, plot=True):
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2)

    # Evaluate the model on the test set
    # TASK: Fill in the evaluation code here

    # Plotting (if enabled)
    if plot:
        plt.figure(figsize=(12, 5))

        # Plot training and validation accuracy
        # TASK: Add code to plot training history

        # Plot model predictions vs. ground truth on the test set
        # TASK: Add code to plot model predictions and ground truth

        plt.show()

    # TASK: Print or return any other metrics or plots you think are necessary

# Example of using the function with a specific architecture
model = build_model(num_layers=2, num_neurons=10)
train_and_evaluate_model(model, epochs=1000)

# %% [markdown]
# # Experimentation
# ## Task 1: Underfitting
# 1. Create and train a model with very few layers and/or neurons (e.g., 1 layer with 5 neurons).
# 2. Evaluate Performance:
#     * Plot training and validation accuracy over epochs.
#     * Plot model predictions vs. ground truth on the test data.
#     * Analyze if the model's performance is poor on both training and test data, which indicates underfitting.
# ## Task 2: Overfitting
# 1. Create a model with an excessive number of layers and/or neurons (e.g., 5 layers with 100 neurons each) and increased number of epochs.
# 2. Evaluate Performance:
#     * Observe the training and validation accuracy plots for a wide gap, indicating overfitting.
#     * Compare model predictions with ground truth for the test data.
#     * Look for high training accuracy but poor test accuracy.
# ## Task 3: Balanced Model
# 1. Experiment to find a balanced architecture.
# 2. Evaluate Performance:
#     * Ensure the training and validation accuracy are both high and close to each other.
#     * The model's predictions should closely match the ground truth for the test data.
#     * The model should not show signs of significant underfitting or overfitting.

# %% [markdown]
# # Evaluation and Analysis
# Use similar evaluation and visualization code as in the previous exercise to assess model performance.
# Answer questions like:
# 1. What signs of underfitting did you observe?
# 2. What were the indications of overfitting?
# 3. Describe the architecture of the balanced model and its performance.
#
# # Conclusion
# Reflect on the importance of matching model complexity with the problem complexity and discuss the trade-offs involved in designing neural network architectures.

# %% [markdown]
# ------------------

# %% [markdown]
# # Regularization Technique: Early Stopping
# ## Objective
# Understand how early stopping can be used as a regularization technique to prevent overfitting and improve the generalization of neural networks.
#
# ## Background
# Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method, such as gradient descent. It involves stopping the training process if the model's performance on a validation set starts to deteriorate, meaning the model begins to learn noise and details from the training data that negatively impact its performance on unseen data.
#
# ## How Early Stopping Works
# * Monitor the model's performance on a validation set during training.
# * If the performance on the validation set stops improving or starts to worsen, stop the training.
# * Often, a 'patience' parameter is set to allow some leeway, meaning training will stop only after the model's performance hasn't improved for a specified number of epochs.

# %% [markdown]
# # Implementation in TensorFlow
# TensorFlow provides an easy way to implement early stopping through callbacks. Here’s how you can add early stopping to your training process:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an EarlyStopping callback instance
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Include this callback in the model's fit method
model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.6083 - accuracy: 0.8396 - val_loss: 0.6027 - val_accuracy: 0.8450
# Epoch 2/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5992 - accuracy: 0.8462 - val_loss: 0.5936 - val_accuracy: 0.8467
# Epoch 3/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.8400 - val_loss: 0.5822 - val_accuracy: 0.8550
# Epoch 4/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5790 - accuracy: 0.8583 - val_loss: 0.5705 - val_accuracy: 0.8583
# Epoch 5/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5682 - accuracy: 0.8600 - val_loss: 0.5601 - val_accuracy: 0.8633
# Epoch 6/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5571 - accuracy: 0.8617 - val_loss: 0.5496 - val_accuracy: 0.8617
# Epoch 7/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.8721 - val_loss: 0.5356 - val_accuracy: 0.8733
# Epoch 8/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5333 - accuracy: 0.8775 - val_loss: 0.5247 - val_accuracy: 0.8750
# Epoch 9/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.8800 - val_loss: 0.5101 - val_accuracy: 0.8850
# Epoch 10/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5085 - accuracy: 0.8913 - val_loss: 0.4969 - val_accuracy: 0.8917
# Epoch 11/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4955 - accuracy: 0.8996 - val_loss: 0.4850 - val_accuracy: 0.8967
# Epoch 12/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4824 - accuracy: 0.9046 - val_loss: 0.4712 - val_accuracy: 0.9117
# Epoch 13/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.9262 - val_loss: 0.4583 - val_accuracy: 0.9267
# Epoch 14/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.9329 - val_loss: 0.4435 - val_accuracy: 0.9433
# Epoch 15/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4410 - accuracy: 0.9533 - val_loss: 0.4301 - val_accuracy: 0.9433
# Epoch 16/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.9600 - val_loss: 0.4168 - val_accuracy: 0.9483
# Epoch 17/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.9696 - val_loss: 0.4014 - val_accuracy: 0.9683
# Epoch 18/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.9717 - val_loss: 0.3875 - val_accuracy: 0.9700
# Epoch 19/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.9742 - val_loss: 0.3741 - val_accuracy: 0.9717
# Epoch 20/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.9800 - val_loss: 0.3614 - val_accuracy: 0.9767
# Epoch 21/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.9829 - val_loss: 0.3467 - val_accuracy: 0.9783
# Epoch 22/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.9837 - val_loss: 0.3343 - val_accuracy: 0.9783
# Epoch 23/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.3277 - accuracy: 0.9875 - val_loss: 0.3200 - val_accuracy: 0.9783
# Epoch 24/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3144 - accuracy: 0.9875 - val_loss: 0.3081 - val_accuracy: 0.9783
# Epoch 25/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3015 - accuracy: 0.9883 - val_loss: 0.2941 - val_accuracy: 0.9800
# Epoch 26/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2891 - accuracy: 0.9892 - val_loss: 0.2828 - val_accuracy: 0.9783
# Epoch 27/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.9892 - val_loss: 0.2715 - val_accuracy: 0.9800
# Epoch 28/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.9896 - val_loss: 0.2610 - val_accuracy: 0.9833
# Epoch 29/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2545 - accuracy: 0.9896 - val_loss: 0.2504 - val_accuracy: 0.9850
# Epoch 30/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9908 - val_loss: 0.2402 - val_accuracy: 0.9850
# Epoch 31/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9900 - val_loss: 0.2303 - val_accuracy: 0.9850
# Epoch 32/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2243 - accuracy: 0.9908 - val_loss: 0.2206 - val_accuracy: 0.9833
# Epoch 33/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2151 - accuracy: 0.9896 - val_loss: 0.2142 - val_accuracy: 0.9850
# Epoch 34/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2065 - accuracy: 0.9912 - val_loss: 0.2044 - val_accuracy: 0.9867
# Epoch 35/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1983 - accuracy: 0.9912 - val_loss: 0.1963 - val_accuracy: 0.9867
# Epoch 36/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9921 - val_loss: 0.1888 - val_accuracy: 0.9867
# Epoch 37/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1831 - accuracy: 0.9917 - val_loss: 0.1818 - val_accuracy: 0.9867
# Epoch 38/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9912 - val_loss: 0.1753 - val_accuracy: 0.9867
# Epoch 39/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1688 - accuracy: 0.9917 - val_loss: 0.1685 - val_accuracy: 0.9867
# Epoch 40/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1624 - accuracy: 0.9925 - val_loss: 0.1623 - val_accuracy: 0.9867
# Epoch 41/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 0.9921 - val_loss: 0.1571 - val_accuracy: 0.9867
# Epoch 42/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9925 - val_loss: 0.1517 - val_accuracy: 0.9867
# Epoch 43/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1448 - accuracy: 0.9921 - val_loss: 0.1460 - val_accuracy: 0.9867
# Epoch 44/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9921 - val_loss: 0.1404 - val_accuracy: 0.9867
# Epoch 45/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9921 - val_loss: 0.1353 - val_accuracy: 0.9867
# Epoch 46/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9921 - val_loss: 0.1310 - val_accuracy: 0.9867
# Epoch 47/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9921 - val_loss: 0.1268 - val_accuracy: 0.9867
# Epoch 48/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9925 - val_loss: 0.1230 - val_accuracy: 0.9867
# Epoch 49/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9925 - val_loss: 0.1193 - val_accuracy: 0.9883
# Epoch 50/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1121 - accuracy: 0.9933 - val_loss: 0.1146 - val_accuracy: 0.9883
# Epoch 51/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.9929 - val_loss: 0.1115 - val_accuracy: 0.9883
# Epoch 52/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9933 - val_loss: 0.1074 - val_accuracy: 0.9883
# Epoch 53/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9929 - val_loss: 0.1044 - val_accuracy: 0.9883
# Epoch 54/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9925 - val_loss: 0.1007 - val_accuracy: 0.9900
# Epoch 55/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9933 - val_loss: 0.0976 - val_accuracy: 0.9900
# Epoch 56/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9937 - val_loss: 0.0951 - val_accuracy: 0.9917
# Epoch 57/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.9942 - val_loss: 0.0917 - val_accuracy: 0.9900
# Epoch 58/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9937 - val_loss: 0.0896 - val_accuracy: 0.9917
# Epoch 59/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9937 - val_loss: 0.0874 - val_accuracy: 0.9917
# Epoch 60/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9946 - val_loss: 0.0850 - val_accuracy: 0.9917
# Epoch 61/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.9942 - val_loss: 0.0820 - val_accuracy: 0.9917
# Epoch 62/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0755 - accuracy: 0.9946 - val_loss: 0.0798 - val_accuracy: 0.9917
# Epoch 63/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9946 - val_loss: 0.0768 - val_accuracy: 0.9900
# Epoch 64/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9958 - val_loss: 0.0758 - val_accuracy: 0.9917
# Epoch 65/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 0.9946 - val_loss: 0.0729 - val_accuracy: 0.9917
# Epoch 66/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9950 - val_loss: 0.0711 - val_accuracy: 0.9933
# Epoch 67/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9946 - val_loss: 0.0691 - val_accuracy: 0.9917
# Epoch 68/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9950 - val_loss: 0.0678 - val_accuracy: 0.9933
# Epoch 69/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9954 - val_loss: 0.0658 - val_accuracy: 0.9933
# Epoch 70/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.9954 - val_loss: 0.0642 - val_accuracy: 0.9917
# Epoch 71/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9954 - val_loss: 0.0632 - val_accuracy: 0.9933
# Epoch 72/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 0.9958 - val_loss: 0.0607 - val_accuracy: 0.9917
# Epoch 73/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9962 - val_loss: 0.0595 - val_accuracy: 0.9917
# Epoch 74/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9962 - val_loss: 0.0582 - val_accuracy: 0.9917
# Epoch 75/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9962 - val_loss: 0.0568 - val_accuracy: 0.9933
# Epoch 76/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 0.9962 - val_loss: 0.0551 - val_accuracy: 0.9917
# Epoch 77/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9967 - val_loss: 0.0545 - val_accuracy: 0.9933
# Epoch 78/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9971 - val_loss: 0.0523 - val_accuracy: 0.9917
# Epoch 79/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9967 - val_loss: 0.0513 - val_accuracy: 0.9917
# Epoch 80/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9971 - val_loss: 0.0502 - val_accuracy: 0.9917
# Epoch 81/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9971 - val_loss: 0.0491 - val_accuracy: 0.9917
# Epoch 82/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9971 - val_loss: 0.0486 - val_accuracy: 0.9933
# Epoch 83/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9975 - val_loss: 0.0469 - val_accuracy: 0.9933
# Epoch 84/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 0.9971 - val_loss: 0.0459 - val_accuracy: 0.9917
# Epoch 85/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9975 - val_loss: 0.0447 - val_accuracy: 0.9917
# Epoch 86/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 0.9975 - val_loss: 0.0441 - val_accuracy: 0.9933
# Epoch 87/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9971 - val_loss: 0.0431 - val_accuracy: 0.9917
# Epoch 88/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9971 - val_loss: 0.0423 - val_accuracy: 0.9917
# Epoch 89/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9971 - val_loss: 0.0416 - val_accuracy: 0.9933
# Epoch 90/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9975 - val_loss: 0.0410 - val_accuracy: 0.9933
# Epoch 91/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 0.9975 - val_loss: 0.0396 - val_accuracy: 0.9917
# Epoch 92/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.9971 - val_loss: 0.0395 - val_accuracy: 0.9933
# Epoch 93/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9975 - val_loss: 0.0386 - val_accuracy: 0.9933
# Epoch 94/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9975 - val_loss: 0.0376 - val_accuracy: 0.9933
# Epoch 95/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9975 - val_loss: 0.0368 - val_accuracy: 0.9933
# Epoch 96/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9975 - val_loss: 0.0365 - val_accuracy: 0.9933
# Epoch 97/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9975 - val_loss: 0.0357 - val_accuracy: 0.9933
# Epoch 98/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9979 - val_loss: 0.0348 - val_accuracy: 0.9933
# Epoch 99/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9979 - val_loss: 0.0350 - val_accuracy: 0.9950
# Epoch 100/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9979 - val_loss: 0.0337 - val_accuracy: 0.9933

# %% [markdown]
# ## Task
# 1. Add early stopping to your neural network training process using the above code snippet.
# 2. Experiment with different values for the patience parameter and observe how it impacts the training process and the model's performance.
#
# ## Analysis and Questions
# * How does early stopping affect the number of epochs for which your model trains?
# * Did you observe any improvements in the generalization of your model to the test data?
# * How does the patience parameter impact the effectiveness of early stopping?
#
# ## Conclusion
# Reflect on the importance of regularization techniques like early stopping in preventing overfitting and improving model generalization.
